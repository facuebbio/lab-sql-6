# %%
import pandas as pd
import numpy as np

# %%
file_path = "files_for_lab/films_2020.csv"
df = pd.read_csv(file_path)
df
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2020
# 1    A Astounding Epistle of a Database Administrat...          2020
# 2    A Astounding Reflection of a Lumberjack And a ...          2020
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2020
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2020
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2020
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2020
# 1    A Astounding Epistle of a Database Administrat...          2020
# 2    A Astounding Reflection of a Lumberjack And a ...          2020
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2020
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2020
# ..                                                 ...           ...
# ...

# %%
df.drop_duplicates()
# Out:
#      film_id              title  \
# 0          1   ACADEMY DINOSAUR
# 1          2     ACE GOLDFINGER
# 2          3   ADAPTATION HOLES
# 3          4   AFFAIR PREJUDICE
# 4          5        AFRICAN EGG
# ..       ...                ...
# 995      996     YOUNG LANGUAGE
# 996      997         YOUTH KICK
# 997      998       ZHIVAGO CORE
# 998      999  ZOOLANDER FICTION
# 999     1000          ZORRO ARK
#
#                                            description  release_year  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...          2020
# 1    A Astounding Epistle of a Database Administrat...          2020
# 2    A Astounding Reflection of a Lumberjack And a ...          2020
# 3    A Fanciful Documentary of a Frisbee And a Lumb...          2020
# 4    A Fast-Paced Documentary of a Pastry Chef And ...          2020
# ..                                                 ...           ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...          2020
# ...
